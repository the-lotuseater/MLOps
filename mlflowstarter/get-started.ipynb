# %%
## ML Flow tracking server
# !pip install mlflow
# Out:
# ...
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#    ---------------------------------------- 8.8/8.8 MB 78.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 128.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 32.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 3.5/3.5 MB 68.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/752.6 kB ? eta -:--:--
#    ---------------------------------------- 752.6/752.6 kB 30.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 83.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
# ...

# %%
import mlflow

# %%
mlflow.set_tracking_uri('http://127.0.0.1:5000') #any expirements done on mlflow are tracked here.

# %%
mlflow.set_experiment('check localhost connection')
with mlflow.start_run():
    mlflow.log_metric('test',1)
    mlflow.log_metric('hardy',2)
# Out:
# 🏃 View run rare-auk-571 at: http://127.0.0.1:5000/#/experiments/318673447821355507/runs/3a5757ffe803442886074535e54b580f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/318673447821355507

# %%
with mlflow.start_run():
    mlflow.log_metric('test_1',1)
    mlflow.log_metric('hardy_1',2)
# Out:
# 🏃 View run traveling-ape-480 at: http://127.0.0.1:5000/#/experiments/318673447821355507/runs/2ad4761887184b349956c045bd669cf1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/318673447821355507
